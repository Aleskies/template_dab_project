# %% [markdown]
# # 02_Feature_Engineering
# Transformaciones, creación de variables y guardado de datasets procesados.

# %%
from src.data.load import load_data
print('Feature engineering notebook')
